# %% [markdown]
# # 2016 / 2017
#
# Progress points for the premier league season 2016/2017.

# %%
# %config InlineBackend.figure_formats = ['svg']
from proggyleg import proggyleg

year = 2016

# %% [markdown]
# ## Cumulative Points
#
# The sum of points up to a given game played.

# %%
proggyleg.autoplot(year, "cumulative");

# %% [markdown]
# ## Extrapolated Points
#
# The sum of points assuming each team continues to score points at the same rate as they have so far.

# %%
proggyleg.autoplot(year, "extrapolated");

# %% [markdown]
# ## Position

# %%
proggyleg.autoplot(year, "position");

# %% [markdown]
# ## Position

# %%
proggyleg.autoplot(year, "position");

# %% [markdown]
# ## Rolling Form
#
# The average points per game over the last 5 games.

# %%
proggyleg.autoplot(year, "form");
