# %%
from proggyleg.proggyleg import generate_notebook_doc, execute_notebook_doc

for league in ("E0",):
    for year in range(1993, 2024):
        generate_notebook_doc(year, league)
        execute_notebook_doc(year, league)
# Out:
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1993.ipynb to notebook
# [NbConvertApp] Writing 1387172 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1993.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1994.ipynb to notebook
# [NbConvertApp] Writing 1385516 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1994.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1995.ipynb to notebook
# [NbConvertApp] Writing 1226379 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1995.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1996.ipynb to notebook
# [NbConvertApp] Writing 1214152 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1996.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1997.ipynb to notebook
# [NbConvertApp] Writing 1212705 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1997.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1998.ipynb to notebook
# [NbConvertApp] Writing 1211441 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1998.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1999.ipynb to notebook
# [NbConvertApp] Writing 1198439 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/1999.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2000.ipynb to notebook
# [NbConvertApp] Writing 1203552 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2000.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2001.ipynb to notebook
# [NbConvertApp] Writing 1202209 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2001.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2002.ipynb to notebook
# [NbConvertApp] Writing 1206181 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2002.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2003.ipynb to notebook
# [NbConvertApp] Writing 1191184 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2003.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2004.ipynb to notebook
# [NbConvertApp] Writing 1198724 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2004.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2005.ipynb to notebook
# [NbConvertApp] Writing 1195298 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2005.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2006.ipynb to notebook
# [NbConvertApp] Writing 1199763 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2006.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2007.ipynb to notebook
# [NbConvertApp] Writing 1212588 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2007.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2008.ipynb to notebook
# [NbConvertApp] Writing 1192364 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2008.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2009.ipynb to notebook
# [NbConvertApp] Writing 1205358 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2009.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2010.ipynb to notebook
# [NbConvertApp] Writing 1205524 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2010.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2011.ipynb to notebook
# [NbConvertApp] Writing 1197913 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2011.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2012.ipynb to notebook
# [NbConvertApp] Writing 1197753 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2012.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2013.ipynb to notebook
# [NbConvertApp] Writing 1195403 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2013.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2014.ipynb to notebook
# [NbConvertApp] Writing 1211559 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2014.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2015.ipynb to notebook
# [NbConvertApp] Writing 1205726 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2015.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2016.ipynb to notebook
# [NbConvertApp] Writing 1203177 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2016.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2017.ipynb to notebook
# [NbConvertApp] Writing 1201978 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2017.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2018.ipynb to notebook
# [NbConvertApp] Writing 1191121 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2018.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2019.ipynb to notebook
# [NbConvertApp] Writing 1206597 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2019.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2020.ipynb to notebook
# [NbConvertApp] Writing 1198012 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2020.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2021.ipynb to notebook
# [NbConvertApp] Writing 1191268 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2021.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2022.ipynb to notebook
# [NbConvertApp] Writing 1194468 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2022.ipynb
# [NbConvertApp] Converting notebook /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2023.ipynb to notebook
# [NbConvertApp] Writing 1062184 bytes to /media/johnnie/Storage2TB/Sync/dev/python/proggyleg/docs/E0/2023.ipynb

# %%
from proggyleg.proggyleg import generate_notebook_doc, execute_notebook_doc

for league in ("E1",):
    for year in range(2004, 2024):
        generate_notebook_doc(year, league)
        execute_notebook_doc(year, league)
# Out:
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2004.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1582137 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2004.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2005.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1576171 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2005.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2006.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1589275 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2006.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2007.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1591364 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2007.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2008.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1589162 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2008.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2009.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1591015 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2009.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2010.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1589397 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2010.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2011.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1577597 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2011.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2012.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1584643 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2012.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2013.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1580203 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2013.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2014.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1566751 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2014.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2015.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1579315 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2015.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2016.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1576441 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2016.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2017.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1583484 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2017.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2018.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1584110 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2018.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2019.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1564882 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2019.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2020.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1582344 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2020.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2021.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1582814 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2021.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2022.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1583488 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2022.ipynb
# [NbConvertApp] Converting notebook /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2023.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 1459786 bytes to /Users/johnnie/Sync/dev/python/proggyleg/docs/E1/2023.ipynb
