# %% [markdown]
# # generate single plots

# %%
# %config InlineBackend.figure_formats = ['svg']
from proggyleg.proggyleg import autoplot  # noqa

year = 2023
for league in [
    # 'E0',
    'E1',
    # 'E2',
    # 'SP1',
    # 'I1',
    # 'D1',
    # 'SC0',
]:
    fig, ax = autoplot(year=year, league=league, which="extrapolated", markersize=5, linewidth=2.5, markeredgewidth=0.25)
    # fig.savefig(f"plots/{league}_{year}.png", dpi=300, bbox_inches='tight')
